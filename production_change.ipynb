# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Study data files
crop_production_path = "crop_production_clean.csv"
temp_file_path = "temperature_clean.csv"

# %%
crop_pro_results = pd.read_csv(crop_production_path,encoding="ISO-8859-1")
temp_read_results = pd.read_csv(temp_file_path,encoding="ISO-8859-1")
crop_pro_results =crop_pro_results[ ["Area","Item"] + list(crop_pro_results.loc[:,"Y1961":"Y2013"]) ]
crop_pro_results

#rename the columns for crop file 
renamed_crop_column=[]
for col in crop_pro_results.columns:
    renamed_crop_column.append(f'{col}_crop')
    
crop_pro_results.columns =renamed_crop_column


#compare with temp file country names
area_col=crop_pro_results["Area_crop"].unique()

# %%
# Temperature data set
temp_avg =temp_read_results[["AverageTemperature","year","Country"]]
temp_avg_df=pd.DataFrame(temp_avg).set_index("year")
temp_avg_df = temp_avg_df.reset_index()#.groupby("Country","year").AverageTemperature.mean()
temp_avg_grouped =pd.DataFrame(temp_avg_df).groupby(["Country","year"]).AverageTemperature.mean()
temp_avg_grouped=temp_avg_grouped.unstack()

#reset index to make country a column for merging
temp_avg_grouped=temp_avg_grouped.reset_index()


# Rename the columns for temp file
renamed_column =[]
for column in temp_avg_grouped.columns:
    renamed_column.append(f'{column}Temp')
    
temp_avg_grouped.columns =renamed_column
temp_avg_sorted=temp_avg_grouped.sort_values("CountryTemp")


#crop_results_sorted =crop_pro_results.sort_values("Area_crop")

#Rename country to match our country of focus
crop_country_list =temp_avg_sorted["CountryTemp"].values
for index,value in enumerate(crop_country_list):
    if value =="United States":#"United States of America"
        print(f'index:{index},value:{value}')
        #rename the country to match crop file for merging
        temp_avg_sorted["CountryTemp"][232]="United States of America"


#compare with crop file columns
#country_col =temp_avg_sorted["CountryTemp"].unique()
# Out:
# index:232,value:United States
# C:\Users\Liam\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Merge the two data sets
combined_crop_temp_df= crop_pro_results.merge(temp_avg_sorted, how ="outer",left_on='Area_crop', right_on="CountryTemp", suffixes=(False, False))
combined_crop_temp_df =combined_crop_temp_df.dropna()

# %%
# Crop production in the US
usa_prod_df = combined_crop_temp_df.loc[combined_crop_temp_df['Area_crop']=="United States of America"]
usa_prod_df
# Out:
#                      Area_crop                 Item_crop  Y1961_crop  \
# 2929  United States of America        Wheat and products     13439.0
# 2930  United States of America  Rice (Milled Equivalent)       481.0
# 2931  United States of America       Barley and products       131.0
# 2932  United States of America        Maize and products      1470.0
# 2933  United States of America          Rye and products       112.0
# ...                        ...                       ...         ...
# 3000  United States of America                    Offals       376.0
# 3001  United States of America               Animal fats      2106.0
# 3002  United States of America                      Eggs      3342.0
# 3003  United States of America   Milk - Excluding Butter     50289.0
# 3004  United States of America             Fish, Seafood      2465.0
#
#       Y1962_crop  Y1963_crop  Y1964_crop  Y1965_crop  Y1966_crop  Y1967_crop  \
# 2929     13314.0     13320.0     13525.0     13510.0     13479.0     13717.0
# 2930       574.0       518.0       564.0       620.0       589.0       611.0
# 2931       131.0       152.0       152.0       152.0       152.0       180.0
# 2932      1499.0      1526.0      1570.0      1628.0      1714.0      1694.0
# 2933       119.0       119.0       122.0       116.0       122.0       125.0
# ...          ...         ...         ...         ...         ...         ...
# 3000       381.0       390.0       391.0       397.0       405.0       425.0
# 3001      2219.0      2132.0      2077.0      2060.0      1848.0      1935.0
# 3002      3409.0      3424.0      3521.0      3526.0      3559.0      3695.0
# 3003     49326.0     50260.0     50967.0     50757.0     51203.0     50105.0
# 3004      2568.0      2540.0      2512.0      2566.0      2680.0      2582.0
#
#       Y1968_crop  ...  2002Temp  2003Temp  2004Temp  2005Temp  2006Temp  \
# 2929     13840.0  ...  9.816167  9.755083    9.6675  9.892667    9.9745
# 2930       645.0  ...  9.816167  9.755083    9.6675  9.892667    9.9745
# 2931       174.0  ...  9.816167  9.755083    9.6675  9.892667    9.9745
# 2932      1489.0  ...  9.816167  9.755083    9.6675  9.892667    9.9745
# 2933       135.0  ...  9.816167  9.755083    9.6675  9.892667    9.9745
# ...          ...  ...       ...       ...       ...       ...       ...
# 3000       439.0  ...  9.816167  9.755083    9.6675  9.892667    9.9745
# 3001      1995.0  ...  9.816167  9.755083    9.6675  9.892667    9.9745
# 3002      3667.0  ...  9.816167  9.755083    9.6675  9.892667    9.9745
# 3003     50615.0  ...  9.816167  9.755083    9.6675  9.892667    9.9745
# 3004      2907.0  ...  9.816167  9.755083    9.6675  9.892667    9.9745
#
#       2007Temp  2008Temp  2009Temp  2010Temp  2011Temp
# 2929    9.8375  8.951417  9.137083  9.505583  9.549917
# 2930    9.8375  8.951417  9.137083  9.505583  9.549917
# 2931    9.8375  8.951417  9.137083  9.505583  9.549917
# 2932    9.8375  8.951417  9.137083  9.505583  9.549917
# 2933    9.8375  8.951417  9.137083  9.505583  9.549917
# ...        ...       ...       ...       ...       ...
# 3000    9.8375  8.951417  9.137083  9.505583  9.549917
# 3001    9.8375  8.951417  9.137083  9.505583  9.549917
# 3002    9.8375  8.951417  9.137083  9.505583  9.549917
# 3003    9.8375  8.951417  9.137083  9.505583  9.549917
# 3004    9.8375  8.951417  9.137083  9.505583  9.549917
#
# [76 rows x 107 columns]

# %%
Tot_usa_prod_df =usa_prod_df[list(usa_prod_df.loc[:,"Area_crop":"Y2011_crop"])]
Tot_usa_prod_df["Results"]= Tot_usa_prod_df.apply(lambda column: column['Y1961_crop':'Y2011_crop'].sum(),axis = 1)
Tot_usa_prod_df.head()
# Out:
# C:\Users\Liam\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                      Area_crop                 Item_crop  Y1961_crop  \
# 2929  United States of America        Wheat and products     13439.0
# 2930  United States of America  Rice (Milled Equivalent)       481.0
# 2931  United States of America       Barley and products       131.0
# 2932  United States of America        Maize and products      1470.0
# 2933  United States of America          Rye and products       112.0
#
#       Y1962_crop  Y1963_crop  Y1964_crop  Y1965_crop  Y1966_crop  Y1967_crop  \
# 2929     13314.0     13320.0     13525.0     13510.0     13479.0     13717.0
# 2930       574.0       518.0       564.0       620.0       589.0       611.0
# 2931       131.0       152.0       152.0       152.0       152.0       180.0
# 2932      1499.0      1526.0      1570.0      1628.0      1714.0      1694.0
# 2933       119.0       119.0       122.0       116.0       122.0       125.0
#
#       Y1968_crop  ...  Y2003_crop  Y2004_crop  Y2005_crop  Y2006_crop  \
# 2929     13840.0  ...     24801.0     24511.0     24869.0     25250.0
# 2930       645.0  ...      1827.0      1943.0      2021.0      2075.0
# 2931       174.0  ...       153.0       158.0       152.0       162.0
# 2932      1489.0  ...      3879.0      3879.0      3887.0      3887.0
# 2933       135.0  ...        83.0        83.0        84.0        84.0
#
#       Y2007_crop  Y2008_crop  Y2009_crop  Y2010_crop  Y2011_crop   Results
# 2929     25793.0     25302.0     24959.0     25167.0     25050.0  980782.0
# 2930      2104.0      2104.0      2118.0      2194.0      2127.0   68559.0
# 2931       164.0       169.0       166.0       167.0       164.0    7905.0
# 2932      3887.0      3887.0      3913.0      3954.0      3969.0  137191.0
# 2933        85.0        84.0        83.0        81.0        85.0    4255.0
#
# [5 rows x 54 columns]

# %%
sorted_Tot_usa_prod_df = Tot_usa_prod_df.sort_values(by=['Results'], ascending=False)
#maize_new = final_df[['Area', 'maize production']].copy()
clean_df=sorted_Tot_usa_prod_df.head(10)

# %%
clean_df.drop_duplicates()
# Out:
#                      Area_crop                 Item_crop  Y1961_crop  \
# 3003  United States of America   Milk - Excluding Butter     50289.0
# 2994  United States of America                Vegetables     17713.0
# 2999  United States of America                      Meat     16780.0
# 2995  United States of America   Fruits - Excluding Wine     14529.0
# 2987  United States of America  Cereals - Excluding Beer     16415.0
# 2998  United States of America       Alcoholic Beverages     12623.0
# 2968  United States of America                      Beer     11200.0
# 2929  United States of America        Wheat and products     13439.0
# 2955  United States of America         Vegetables, Other     12011.0
#
#       Y1962_crop  Y1963_crop  Y1964_crop  Y1965_crop  Y1966_crop  Y1967_crop  \
# 3003     49326.0     50260.0     50967.0     50757.0     51203.0     50105.0
# 2994     18628.0     17584.0     17462.0     18097.0     18321.0     19603.0
# 2999     17181.0     18036.0     18920.0     18721.0     19587.0     20583.0
# 2995     15082.0     13671.0     14322.0     15216.0     16297.0     17208.0
# 2987     16166.0     16372.0     16704.0     16851.0     16865.0     17088.0
# 2998     12929.0     13408.0     13993.0     14429.0     15131.0     15550.0
# 2968     11418.0     11869.0     12501.0     12771.0     13340.0     13751.0
# 2929     13314.0     13320.0     13525.0     13510.0     13479.0     13717.0
# 2955     11839.0     12003.0     11488.0     12050.0     12162.0     12909.0
#
#       Y1968_crop  ...  Y2003_crop  Y2004_crop  Y2005_crop  Y2006_crop  \
# 3003     50615.0  ...     76422.0     76008.0     76887.0     76329.0
# 2994     21463.0  ...     37102.0     39107.0     36668.0     37892.0
# 2999     21158.0  ...     36074.0     37160.0     37361.0     37776.0
# 2995     15931.0  ...     33495.0     34329.0     32749.0     32658.0
# 2987     16992.0  ...     32131.0     31979.0     32471.0     32991.0
# 2998     16355.0  ...     29627.0     29971.0     30296.0     30543.0
# 2968     14451.0  ...     25372.0     25810.0     25831.0     26344.0
# 2929     13840.0  ...     24801.0     24511.0     24869.0     25250.0
# 2955     13231.0  ...     22892.0     22046.0     21973.0     22758.0
#
#       Y2007_crop  Y2008_crop  Y2009_crop  Y2010_crop  Y2011_crop    Results
# 3003     78349.0     77704.0     79447.0     78596.0     78752.0  3190275.0
# 2994     39116.0     35699.0     37686.0     37496.0     36650.0  1428504.0
# 2999     38117.0     37598.0     36738.0     37103.0     36621.0  1424232.0
# 2995     33384.0     35303.0     33813.0     32212.0     30768.0  1333916.0
# 2987     33551.0     33107.0     32753.0     33239.0     33139.0  1256437.0
# 2998     30618.0     30397.0     30026.0     30147.0     29713.0  1253627.0
# 2968     26452.0     26183.0     25715.0     25625.0     25379.0  1094878.0
# 2929     25793.0     25302.0     24959.0     25167.0     25050.0   980782.0
# 2955     21697.0     20868.0     20979.0     21798.0     21532.0   868748.0
#
# [9 rows x 54 columns]

# %%
clean_df.groupby("Area_crop").sum()
# Out:
#                           Y1961_crop  Y1962_crop  Y1963_crop  Y1964_crop  \
# Area_crop
# United States of America    215288.0    215209.0    216783.0    220849.0
#
#                           Y1965_crop  Y1966_crop  Y1967_crop  Y1968_crop  \
# Area_crop
# United States of America    223159.0    227588.0    230619.0    234651.0
#
#                           Y1969_crop  Y1970_crop  ...  Y2003_crop  Y2004_crop  \
# Area_crop                                         ...
# United States of America    238019.0    240381.0  ...    394338.0    396929.0
#
#                           Y2005_crop  Y2006_crop  Y2007_crop  Y2008_crop  \
# Area_crop
# United States of America    395992.0    398870.0    405426.0    399865.0
#
#                           Y2009_crop  Y2010_crop  Y2011_crop     Results
# Area_crop
# United States of America    401563.0    399979.0    396356.0  16021674.0
#
# [1 rows x 52 columns]

# %%
#sort by crop  total production
Tot_usa_prod_df =usa_prod_df[list(usa_prod_df.loc[:,"Area_crop":"Y2011_crop"])]
# add column
Tot_usa_prod_df["Country_per_crop_total"]=""
col_list=Tot_usa_prod_df.columns

Total = 0
count = 2
index = 1

for index in range(1,len(Tot_usa_prod_df)-1):
    print(index)
    
    for count in range(2,(len(col_list)-2)):
        print(f'inside{index}')
        print(f'count{count}')
       
        Total += int(Tot_usa_prod_df.iloc[index,count])
        print(f'total{Total}')
        #Tot_usa_prod_df.loc[index,"Country_per_crop_total"]
        count +=1
        break
    Tot_usa_prod_df.loc[:,"Country_per_crop_total"] = Total    
    index +=1 
    
Tot_usa_prod_df.head()
# Out:
# C:\Users\Liam\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Liam\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1
# inside1
# count2
# total481
# 2
# inside2
# count2
# total612
# 3
# inside3
# count2
# total2082
# 4
# inside4
# count2
# total2194
# 5
# inside5
# count2
# total2788
# 6
# inside6
# count2
# total2975
# 7
# inside7
# count2
# total3472
# 8
# inside8
# count2
# total12554
# 9
# inside9
# count2
# total13083
# 10
# inside10
# count2
# total21740
# 11
# inside11
# count2
# total22810
# 12
# inside12
# count2
# total22935
# 13
# inside13
# count2
# total23591
# 14
# inside14
# count2
# total23650
# 15
# inside15
# count2
# total23660
# 16
# inside16
# count2
# total23996
# 17
# inside17
# count2
# total24355
# 18
# inside18
# count2
# total24617
# 19
# inside19
# count2
# total24704
# 20
# inside20
# count2
# total25993
# 21
# inside21
# count2
# total26588
# 22
# inside22
# count2
# total26708
# 23
# inside23
# count2
# total26858
# 24
# inside24
# count2
# total31567
# 25
# inside25
# count2
# total32560
# 26
# inside26
# count2
# total44571
# 27
# inside27
# count2
# total48813
# 28
# inside28
# count2
# total49177
# 29
# inside29
# count2
# total50484
# 30
# inside30
# count2
# total51933
# 31
# inside31
# count2
# total54259
# 32
# inside32
# count2
# total55003
# 33
# inside33
# count2
# total55964
# 34
# inside34
# count2
# total59070
# 35
# inside35
# count2
# total60380
# 36
# inside36
# count2
# total60733
# 37
# inside37
# count2
# total60785
# 38
# inside38
# count2
# total61400
# 39
# inside39
# count2
# total72600
# 40
# inside40
# count2
# total73404
# 41
# inside41
# count2
# total81206
# 42
# inside42
# count2
# total81605
# 43
# inside43
# count2
# total86846
# 44
# inside44
# count2
# total89957
# 45
# inside45
# count2
# total90184
# 46
# inside46
# count2
# total90560
# 47
# inside47
# count2
# total91186
# 48
# inside48
# count2
# total91324
# 49
# inside49
# count2
# total92666
# 50
# inside50
# count2
# total96008
# 51
# inside51
# count2
# total146297
# 52
# inside52
# count2
# total146587
# 53
# inside53
# count2
# total147280
# 54
# inside54
# count2
# total147755
# 55
# inside55
# count2
# total147825
# 56
# inside56
# count2
# total148163
# 57
# inside57
# count2
# total148762
# 58
# inside58
# count2
# total165177
# 59
# inside59
# count2
# total175303
# 60
# inside60
# count2
# total185156
# 61
# inside61
# count2
# total185881
# 62
# inside62
# count2
# total186217
# 63
# inside63
# count2
# total186980
# 64
# inside64
# count2
# total189242
# 65
# inside65
# count2
# total206955
# 66
# inside66
# count2
# total221484
# 67
# inside67
# count2
# total223199
# 68
# inside68
# count2
# total223249
# 69
# inside69
# count2
# total235872
# 70
# inside70
# count2
# total252652
# 71
# inside71
# count2
# total253028
# 72
# inside72
# count2
# total255134
# 73
# inside73
# count2
# total258476
# 74
# inside74
# count2
# total308765
#                      Area_crop                 Item_crop  Y1961_crop  \
# 2929  United States of America        Wheat and products     13439.0
# 2930  United States of America  Rice (Milled Equivalent)       481.0
# 2931  United States of America       Barley and products       131.0
# 2932  United States of America        Maize and products      1470.0
# 2933  United States of America          Rye and products       112.0
#
#       Y1962_crop  Y1963_crop  Y1964_crop  Y1965_crop  Y1966_crop  Y1967_crop  \
# 2929     13314.0     13320.0     13525.0     13510.0     13479.0     13717.0
# 2930       574.0       518.0       564.0       620.0       589.0       611.0
# 2931       131.0       152.0       152.0       152.0       152.0       180.0
# 2932      1499.0      1526.0      1570.0      1628.0      1714.0      1694.0
# 2933       119.0       119.0       122.0       116.0       122.0       125.0
#
#       Y1968_crop  ...  Y2003_crop  Y2004_crop  Y2005_crop  Y2006_crop  \
# 2929     13840.0  ...     24801.0     24511.0     24869.0     25250.0
# 2930       645.0  ...      1827.0      1943.0      2021.0      2075.0
# 2931       174.0  ...       153.0       158.0       152.0       162.0
# 2932      1489.0  ...      3879.0      3879.0      3887.0      3887.0
# 2933       135.0  ...        83.0        83.0        84.0        84.0
#
#       Y2007_crop  Y2008_crop  Y2009_crop  Y2010_crop  Y2011_crop  \
# 2929     25793.0     25302.0     24959.0     25167.0     25050.0
# 2930      2104.0      2104.0      2118.0      2194.0      2127.0
# 2931       164.0       169.0       166.0       167.0       164.0
# 2932      3887.0      3887.0      3913.0      3954.0      3969.0
# 2933        85.0        84.0        83.0        81.0        85.0
#
#       Country_per_crop_total
# 2929
# 2930
# 2931
# 2932
# 2933
#
# [5 rows x 54 columns]

# %%
t=len(Tot_usa_prod_df)
t
print(Tot_usa_prod_df.columns)

# %%
#sorted_usa_df=usa_prod_df[list(crop_pro_results.loc[:,"Area_crop":"Y2011_crop"])]
#yearly_df=crop_pro_df[list(crop_pro_df.loc[:,"Y1961_crop":"Y2013_crop"])]

'''
# add column
yearly_df["Country_per_crop_total"]=""
col_list=yearly_df.columns
Total=0
index =0
count=1
for index in range(len(yearly_df)-1):    
    
    for count in range(len(col_list)-2):
        Total += yearly_df.iloc[index,count]
        count +=1
    yearly_df.loc[index, "Country_per_crop_total"] = Total    
    index +=1 
new_df=pd.DataFrame(yearly_df)
#new_df=new_df[  list(crop_pro_results.loc[:,"Area_crop":"Y2013_crop"]) ]
new_df.head()
'''
Tot_usa_prod_df

# %%
#grouped_crop =crop_pro_results.loc[crop_pro_results["Item_crop"]=="Maize and products"].groupby(["Item_crop","Area_crop"]).sum()
grouped_crop =crop_pro_results.groupby(["Area_crop","Item_crop"]).sum()

grouped_crop_df =pd.DataFrame(grouped_crop)
grouped_crop_df = grouped_crop_df.reset_index()
grouped_crop_df

# %%
crop_unique = pd.DataFrame(crop_pro_results).unique()

# %%
new_df= new_df.sort_index()
new_df
