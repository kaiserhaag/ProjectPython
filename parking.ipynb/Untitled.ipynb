# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# file path
temp = "../temperature_clean.csv"
production = "../crop_production_clean.csv"

# %%
# read csv files
temp_df = pd.read_csv(temp)
#temp_df.head()

# %%
crop_pro_results = pd.read_csv(production, encoding="ISO-8859-1")
crop_pro_results.head()
# Out:
#   Area Abbreviation  Area Code         Area  Item Code  \
# 0               AFG          2  Afghanistan       2805
# 1               AFG          2  Afghanistan       2513
# 2               AFG          2  Afghanistan       2514
# 3               AFG          2  Afghanistan       2531
# 4               AFG          2  Afghanistan       2542
#
#                        Item  Element Code Element         Unit  latitude  \
# 0  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# 1       Barley and products          5142    Food  1000 tonnes     33.94
# 2        Maize and products          5142    Food  1000 tonnes     33.94
# 3     Potatoes and products          5142    Food  1000 tonnes     33.94
# 4    Sugar (Raw Equivalent)          5142    Food  1000 tonnes     33.94
#
#    longitude  ...  Y2004  Y2005  Y2006  Y2007  Y2008  Y2009  Y2010  Y2011  \
# 0      67.71  ...    419    445    546    455    490    415    442    476
# ...

# %%
rice_df = crop_pro_results[crop_pro_results['Item']=="Rice (Milled Equivalent)"]
rice_top_df = rice_df.nlargest(10, "Y1961")
rice_top_df['rice production'] = rice_top_df.sum(axis=1)
rice_top_df.head(2)
final_rice_df = rice_top_df.sort_values(by=['rice production'], ascending=False)
final_rice_df.head(2) 
rice_new = final_rice_df[['Area', 'rice production']].copy()
rice_new = rice_new.set_index("Area")
#rice_new

# %%
ax = rice_new[['rice production']].plot(kind='bar', title ="Top 10 World Rice Producers", figsize=(10, 5), legend=True, fontsize=12)
plt.ylabel("Total Rice Production-1000 tons")
# Out:
# Text(0, 0.5, 'Total Rice Production-1000 tons')

# %%
maize_df = crop_pro_results[crop_pro_results['Item']=="Maize and products"]
maize_top_df = maize_df.nlargest(10, "Y1961")
maize_top_df
maize_top_df['maize production'] = maize_df.sum(axis=1)
maize_top_df
final_maize_df = maize_top_df.sort_values(by=['maize production'], ascending=False)
maize_new = final_df[['Area', 'maize production']].copy()

maize_new = maize_new.set_index("Area")
#maize_new

# %%
ax1 = maize_new[['maize production']].plot(kind='bar', title ="Top 10 World maize Producers", figsize=(10, 5), legend=True, fontsize=12)
plt.ylabel("Total maize Production-1000 tons")
# Out:
# Text(0, 0.5, 'Total maize Production-1000 tons')

# %%
Vegetables_df = crop_pro_results[crop_pro_results['Item']=="Vegetables"]
Vegetables_df
Vegetables_top_df = Vegetables_df.nlargest(10, "Y1961")
Vegetables_top_df
Vegetables_top_df['Vegetables production'] = Vegetables_df.sum(axis=1)
#maize_top_df
final_Vegetables_df = Vegetables_top_df.sort_values(by=['Vegetables production'], ascending=False)
Vegetables_new = final_Vegetables_df[['Area', 'Vegetables production']].copy()

Vegetables_new = Vegetables_new.set_index("Area")
#Vegetables_new

# %%
ax3 = Vegetables_new[['Vegetables production']].plot(kind='bar', title ="Top 10 World Vegetables Producers", figsize=(10, 5), legend=True, fontsize=12)
plt.ylabel("Total Vegetables Production-1000 tons")
# Out:
# Text(0, 0.5, 'Total Vegetables Production-1000 tons')
