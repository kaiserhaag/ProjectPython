# %%
#import dependencies

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

#file to load
temperature_data = "temperature.csv"
crop_data = "crop_production.csv"

#read the temperature and crop data, encoding='ISO-8859-1'
temp_data = pd.read_csv(temperature_data,encoding='ISO-8859-1')
crops_data = pd.read_csv(crop_data,encoding='ISO-8859-1')


#before merge we need to change the column name on crop data [area to country]
crops_clean= crops_data.rename(columns={"Area": "Country"})
crops_clean.head()
# Out:
#   Area Abbreviation  Area Code      Country  Item Code  \
# 0               AFG          2  Afghanistan       2805
# 1               AFG          2  Afghanistan       2513
# 2               AFG          2  Afghanistan       2514
# 3               AFG          2  Afghanistan       2531
# 4               AFG          2  Afghanistan       2542
#
#                        Item  Element Code Element         Unit  latitude  \
# 0  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# 1       Barley and products          5142    Food  1000 tonnes     33.94
# 2        Maize and products          5142    Food  1000 tonnes     33.94
# 3     Potatoes and products          5142    Food  1000 tonnes     33.94
# 4    Sugar (Raw Equivalent)          5142    Food  1000 tonnes     33.94
#
#    longitude  ...  Y2004  Y2005  Y2006  Y2007  Y2008  Y2009  Y2010  Y2011  \
# 0      67.71  ...    419    445    546    455    490    415    442    476
# ...

# %%
#clean temperature dataset 
temp_data.head()
temp_clean= temp_data.groupby(['Country',''()
temp_clean.head()
# Out:
#                 AverageTemperature  AverageTemperatureUncertainty     year
# Country
# Afghanistan               8931.202                        262.090  1215432
# Africa                   14981.862                        114.595  1215432
# Albania                   7964.920                        195.876  1215432
# Algeria                  14412.811                        228.197  1215432
# American Samoa           16492.570                        233.280  1215432

# %%
#combine into a single dataset
temp_crop_data= pd.merge(crops_clean,temp_data, how= "left", on=["Country"])

#display the table 
temp_crop_data.head()
# Out:
#   Area Abbreviation  Area Code      Country  Item Code  \
# 0               AFG          2  Afghanistan       2805
# 1               AFG          2  Afghanistan       2805
# 2               AFG          2  Afghanistan       2805
# 3               AFG          2  Afghanistan       2805
# 4               AFG          2  Afghanistan       2805
#
#                        Item  Element Code Element         Unit  latitude  \
# 0  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# 1  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# 2  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# 3  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# 4  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
#
#    longitude  ...  Y2008  Y2009  Y2010  Y2011  Y2012  Y2013      dt  \
# 0      67.71  ...    490    415    442    476    425    422  1/1/61
# ...

# %%
temp_crop_data.groupby(['Country','Item']).Unit.agg(['sum','mean','max','min'])
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-25-bf3326934549> in <module>
# ----> 1 temp_crop_data.groupby(['Country','Item']).Unit.agg(['sum','mean','max','min'])
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     849             # but not the class list / tuple itself.
#     850             func_or_funcs = _maybe_mangle_lambdas(func_or_funcs)
# --> 851             ret = self._aggregate_multiple_funcs(func_or_funcs, (_level or 0) + 1)
#     852             if relabeling:
#     853                 ret.columns = columns
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _aggregate_multiple_funcs(self, arg, _level)
#     928                 obj._reset_cache()
#     929                 obj._selection = name
# ...
