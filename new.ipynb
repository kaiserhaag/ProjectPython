# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Study data files
crop_production_path = "crop_production_clean.csv"
temp_file_path = "temperature_clean.csv"

crop_pro_results = pd.read_csv(crop_production_path,encoding="ISO-8859-1")
temp_read_results = pd.read_csv(temp_file_path,encoding="ISO-8859-1")
crop_pro_results =crop_pro_results[ ["Area","Item"] + list(crop_pro_results.loc[:,"Y1961":"Y2013"]) ]

# %%
crop_pro_results
# Out:
#              Area                      Item  Y1961  Y1962  Y1963  Y1964  \
# 0     Afghanistan  Rice (Milled Equivalent)    183    183    182    220
# 1     Afghanistan       Barley and products    237    237    237    238
# 2     Afghanistan        Maize and products    403    403    410    415
# 3     Afghanistan     Potatoes and products    111     97    103    110
# 4     Afghanistan    Sugar (Raw Equivalent)     45     41     43     52
# ...           ...                       ...    ...    ...    ...    ...
# 3148     Zimbabwe                Vegetables     73     76     77     79
# 3149     Zimbabwe   Fruits - Excluding Wine     53     57     60     61
# 3150     Zimbabwe       Alcoholic Beverages    210    259    239    242
# 3151     Zimbabwe                      Meat     63     62     64     53
# 3152     Zimbabwe   Milk - Excluding Butter    230    232    234    238
#
#       Y1965  Y1966  Y1967  Y1968  ...  Y2004  Y2005  Y2006  Y2007  Y2008  \
# 0       220    195    231    235  ...    419    445    546    455    490
# 1       238    237    225    227  ...    185     43     44     48     62
# 2       415    413    454    448  ...    231     67     82     67     69
# 3       113    117    128    130  ...    276    294    294    260    242
# 4        55     58     62     65  ...    124    152    169    192    217
# ...     ...    ...    ...    ...  ...    ...    ...    ...    ...    ...
# 3148     82     84     87     90  ...    161    166    208    185    137
# 3149     60     56     56     58  ...    191    134    167    177    185
# 3150    246    293    284    297  ...    294    290    316    355    398
# 3151     51     56     46     52  ...    222    228    233    238    242
# 3152    234    231    231    248  ...    373    357    359    356    341
#
#       Y2009  Y2010  Y2011  Y2012  Y2013
# 0       415    442    476    425    422
# 1        55     60     72     78     89
# 2        71     82     73     77     76
# 3       250    192    169    196    230
# 4       231    240    240    250    255
# ...     ...    ...    ...    ...    ...
# 3148    179    215    217    227    227
# 3149    184    211    230    246    217
# 3150    437    448    476    525    516
# 3151    265    262    277    280    258
# 3152    385    418    457    426    451
#
# [3153 rows x 55 columns]

# %%
temp_read_results
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0        1/1/1961              -1.463                          0.693
# 1        2/1/1961               1.178                          0.663
# 2        3/1/1961               2.396                          0.420
# 3        4/1/1961               3.051                          0.661
# 4        5/1/1961               7.503                          0.622
# ...           ...                 ...                            ...
# 148711   8/1/2011              17.883                          0.328
# 148712   9/1/2011              22.902                          0.612
# 148713  10/1/2011              24.966                          0.441
# 148714  11/1/2011              25.521                          0.318
# 148715  12/1/2011              24.013                          0.356
#
#          Country  year
# 0         Ã
# land  1961
# 1         Ã
# land  1961
# 2         Ã
# land  1961
# 3         Ã
# land  1961
# 4         Ã
# land  1961
# ...          ...   ...
# 148711  Zimbabwe  2011
# 148712  Zimbabwe  2011
# 148713  Zimbabwe  2011
# 148714  Zimbabwe  2011
# 148715  Zimbabwe  2011
#
# [148716 rows x 5 columns]

# %%
#rename the columns for crop file
renamed_crop_column=[]
for col in crop_pro_results.columns:
    renamed_crop_column.append(f'{col}_crop')
crop_pro_results.columns =renamed_crop_column
crop_pro_results.head()
# Out:
#      Area_crop                 Item_crop  Y1961_crop  Y1962_crop  Y1963_crop  \
# 0  Afghanistan  Rice (Milled Equivalent)         183         183         182
# 1  Afghanistan       Barley and products         237         237         237
# 2  Afghanistan        Maize and products         403         403         410
# 3  Afghanistan     Potatoes and products         111          97         103
# 4  Afghanistan    Sugar (Raw Equivalent)          45          41          43
#
#    Y1964_crop  Y1965_crop  Y1966_crop  Y1967_crop  Y1968_crop  ...  \
# 0         220         220         195         231         235  ...
# 1         238         238         237         225         227  ...
# 2         415         415         413         454         448  ...
# 3         110         113         117         128         130  ...
# 4          52          55          58          62          65  ...
#
#    Y2004_crop  Y2005_crop  Y2006_crop  Y2007_crop  Y2008_crop  Y2009_crop  \
# 0         419         445         546         455         490         415
# 1         185          43          44          48          62          55
# 2         231          67          82          67          69          71
# 3         276         294         294         260         242         250
# 4         124         152         169         192         217         231
#
#    Y2010_crop  Y2011_crop  Y2012_crop  Y2013_crop
# 0         442         476         425         422
# 1          60          72          78          89
# 2          82          73          77          76
# 3         192         169         196         230
# 4         240         240         250         255
#
# [5 rows x 55 columns]

# %%
# Temperature data set
yearly_temp_avg =temp_read_results[["AverageTemperature","year","Country"]]
yearly_temp_avg_df=pd.DataFrame(yearly_temp_avg).set_index("year")
yearly_temp_avg_df = yearly_temp_avg_df.reset_index()#.groupby("Country","year").AverageTemperature.mean()
yearly_temp_avg_grouped =pd.DataFrame(yearly_temp_avg_df).groupby(["Country","year"]).AverageTemperature.mean()

# %%
#usa_prod_df = combined_crop_temp_df.loc[combined_crop_temp_df["Area_crop"]=="United States of America"]
#usa_prod_df
